# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# |Column|Description|
# |:------:|:---:|
# |<code>ServiceType</code>|Service type|
# |<code>TypedStrings</code>|List of user typed strings in chronological order|
# |<code>AcceptString</code>|String that was finally selected|
#
# #
# |Column|Description|
# |:------:|:---:|
# |<code>City EN</code>|English name of the city|
# |<code>City FA</code>|Persian name of the city|
# |<code>Province</code>|Province|
# |<code>Countise</code>|County|
# |<code>District</code>|District|
# |<code>Latitude</code>|
# |<code>Longitude</code>|
# |<code>Area</code>|Area (square kilometers)|
# |<code>Elevation</code>|Elevation (meters)|
# |<code>2016 Census</code>|Population 2016|
# |<code>2011 Census</code>|Population 2011|
# |<code>Wikipedia EN</code>|English Wikipedia link|
# |<code>Wikipedia FA</code>|Persian Wikipedia link|
# |<code>GeoHack</code>|GeoHack site link|

# %%
data = pd.read_json('./data/mrbilit_search.json')
data.head()
# Out:
#   ServiceType                                       TypedStrings  \
# 0      flight                                     [, ف, فل, فلو]
# 1       hotel  [, H, H,, H, , آ, آو, آوا, آواپ, آواپل, آواپلا...
# 2       hotel       [, آ, آو, آوا, آواپ, آواپل, آواپلا, آواپلاس]
# 3       hotel                                                 []
# 4         bus                                                 []
#
#                    AcceptString
# 0                       فلورانس
# 1                         شیراز
# 2                       آواپلاس
# 3  بین المللی اسپیناس خلیج فارس
# 4                         تهران

# %%
cities = pd.read_csv('./data/iran_cities.csv')
cities.head()
# Out:
#      City EN City FA Province Countise District   Latitude  Longitude  \
# 0     Ab Bar   آب‌بر    زنجان     طارم    مرکزی  36.918100  48.964700
# 1  Ab Pakhsh  آب‌پخش    بوشهر  دشتستان   آب‌پخش  29.363706  51.070180
# 2       Abad    آباد    بوشهر  تنگستان    مرکزی  29.028300  51.249100
# 3     Abadan  آبادان  خوزستان   آبادان    مرکزی  30.339167  48.304167
# 4     Abadeh   آباده     فارس    آباده    مرکزی  31.180000  52.670000
#
#        Area  Elevation  2016 Census  2011 Census  \
# 0     709.0        NaN       8091.0       6725.0
# 1  251204.0     7003.0      18913.0      17238.0
# 2      45.0        NaN       3787.0       3787.0
# 3       3.0        NaN     231476.0     212744.0
# 4    1890.0        NaN      59116.0      55758.0
#
#                                   Wikipedia EN  \
# 0         https://en.wikipedia.org/wiki/Ab_Bar
# 1      https://en.wikipedia.org/wiki/Ab_Pakhsh
# 2  https://en.wikipedia.org/wiki/Abad,_Bushehr
# 3   https://en.wikipedia.org/wiki/Abadan,_Iran
# 4         https://en.wikipedia.org/wiki/Abadeh
#
#                                         Wikipedia FA  \
# 0  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%E2%...
# 1  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%E2%...
# 2  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
# 3  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
# 4  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
#
#                                              GeoHack
# 0  https://geohack.toolforge.org/geohack.php?lang...
# 1  https://geohack.toolforge.org/geohack.php?lang...
# 2  https://geohack.toolforge.org/geohack.php?lang...
# 3  https://geohack.toolforge.org/geohack.php?lang...
# 4  https://geohack.toolforge.org/geohack.php?lang...

# %%
percentages = {'bus': 0,
               'flight': 0,
               'train': 0,
               'hotel': 0,
               'taxi': 0,
               'ship': 0}

# %%
percentages = data['ServiceType'].value_counts(normalize=True).to_dict()
percentages
# Out:
# {'bus': 0.40237178034594756,
#  'flight': 0.24959589092831785,
#  'train': 0.17912229020318754,
#  'hotel': 0.10012840849006722,
#  'taxi': 0.05196767127426543,
#  'ship': 0.016813958758214367}

# %%
fig = px.pie(values=percentages.values(),
             names=list(percentages.keys()),
             title='Pie Chart of Service Types')
fig.show()

# %%
preprocessed_data = data.copy()

# %%
preprocessed_data[preprocessed_data['AcceptString'].str.contains('- پایانه')]
# Out:
#       ServiceType                     TypedStrings             AcceptString
# 225           bus             [, ش, شي, شير, شيرا]  شیراز - پایانه امیرکبیر
# 878           bus  [, , , ت, ته, تهر, تهرا, تهران]      تهران - پایانه جنوب
# 1003          bus                     [, شی, شیرا]  شیراز - پایانه کاراندیش
# 1031          bus                               []      تهران - پایانه جنوب
# 1178          bus                          [ت, ته]     تهران - پایانه بیهقی
# ...           ...                              ...                      ...
# 65919         bus                     [, ص, صغ, ص]      اصفهان - پایانه صفه
# 65929         bus                               []  شیراز - پایانه کاراندیش
# 65971         bus                               []  شیراز - پایانه کاراندیش
# 66175         bus                               []      اصفهان - پایانه صفه
# 66194         bus                               []      اصفهان - پایانه صفه
#
# [598 rows x 3 columns]

# %%
def get_city_name(x):
    # extract the city name
    city_name = x.split('-')[0]
    # remove whitespace
    city_name = ' '.join(city_name.split())
    return city_name

matched = preprocessed_data.loc[preprocessed_data['AcceptString'].str.contains('- پایانه'), 'AcceptString']
preprocessed_data.loc[preprocessed_data['AcceptString'].str.contains('- پایانه'), 'AcceptString'] = matched.transform(lambda x: get_city_name(x))

# %%
preprocessed_data[preprocessed_data['AcceptString'].str.contains('- پایانه')]
# Out:
# Empty DataFrame
# Columns: [ServiceType, TypedStrings, AcceptString]
# Index: []

# %%
data_transport = preprocessed_data[data['ServiceType'] != 'hotel']

# %%
top_cities = data_transport['AcceptString'].value_counts()[:20].index.tolist()
top_cities
# Out:
# ['تهران',
#  'مشهد',
#  'اصفهان',
#  'شیراز',
#  'یزد',
#  'بندرعباس',
#  'اهواز',
#  'قم',
#  'تبریز',
#  'کرمان',
#  'رشت',
#  'کرج',
#  'ساری',
#  'کیش',
#  'کرمانشاه',
#  'گرگان',
#  'زاهدان',
#  'زنجان',
#  'اراک',
#  'آبادان']

# %%
temp = data_transport[data_transport['AcceptString'].isin(top_cities)]
fig = px.histogram(temp, x="AcceptString", title='Histogram of Top 20 Cities')
fig.show()

# %%
merged_data = pd.merge(data_transport, cities, left_on='AcceptString', right_on='City FA', how='inner')
merged_data.head()
# Out:
#   ServiceType TypedStrings AcceptString  City EN City FA Province Countise  \
# 0         bus           []        تهران   Tehran   تهران    تهران    تهران
# 1         bus      [تهران]        تهران   Tehran   تهران    تهران    تهران
# 2         bus         [, ]       اصفهان  Isfahan  اصفهان      NaN      NaN
# 3        taxi     [اصفهان]       اصفهان  Isfahan  اصفهان      NaN      NaN
# 4      flight           []       اصفهان  Isfahan  اصفهان      NaN      NaN
#
#   District  Latitude  Longitude        Area  Elevation  2016 Census  \
# 0    مرکزی      35.7       51.4  90018004.0     7513.0    8693706.0
# 1    مرکزی      35.7       51.4  90018004.0     7513.0    8693706.0
# 2      NaN       NaN        NaN         NaN        NaN    1961260.0
# 3      NaN       NaN        NaN         NaN        NaN    1961260.0
# 4      NaN       NaN        NaN         NaN        NaN    1961260.0
#
#    2011 Census                           Wikipedia EN  \
# 0    8154051.0   https://en.wikipedia.org/wiki/Tehran
# 1    8154051.0   https://en.wikipedia.org/wiki/Tehran
# 2    1853293.0  https://en.wikipedia.org/wiki/Isfahan
# 3    1853293.0  https://en.wikipedia.org/wiki/Isfahan
# 4    1853293.0  https://en.wikipedia.org/wiki/Isfahan
#
#                                         Wikipedia FA  \
# 0  https://fa.wikipedia.org/wiki/%D8%AA%D9%87%D8%...
# 1  https://fa.wikipedia.org/wiki/%D8%AA%D9%87%D8%...
# 2  https://fa.wikipedia.org/wiki/%D8%A7%D8%B5%D9%...
# 3  https://fa.wikipedia.org/wiki/%D8%A7%D8%B5%D9%...
# 4  https://fa.wikipedia.org/wiki/%D8%A7%D8%B5%D9%...
#
#                                              GeoHack
# 0  https://geohack.toolforge.org/geohack.php?lang...
# 1  https://geohack.toolforge.org/geohack.php?lang...
# 2  https://geohack.toolforge.org/geohack.php?lang...
# 3  https://geohack.toolforge.org/geohack.php?lang...
# 4  https://geohack.toolforge.org/geohack.php?lang...

# %%
counted = merged_data.groupby('Province')['AcceptString'].count().sort_values(ascending=False)
counted
# Out:
# Province
# تهران                  12512
# خراسان رضوی             6021
# خوزستان                 3547
# فارس                    3533
# هرمزگان                 3322
# مازندران                2364
# یزد                     2241
# کرمان                   2076
# آذربایجان شرقی          2001
# قم                      1711
# گیلان                   1576
# سیستان و بلوچستان       1323
# سمنان                   1078
# البرز                    952
# بوشهر                    892
# گلستان                   822
# کرمانشاه                 747
# آذربایجان غربی           676
# اصفهان                   671
# همدان                    650
# مرکزی                    646
# زنجان                    621
# لرستان                   589
# قزوین                    455
# خراسان جنوبی             406
# چهارمحال و بختیاری       297
# ایلام                    268
# اردبیل                   232
# کردستان                  221
# خراسان شمالی             132
# کهگیلویه و بویراحمد       97
# Name: AcceptString, dtype: int64

# %%
top_provinces = counted.index.tolist()[:15]
top_provinces
# Out:
# ['تهران',
#  'خراسان رضوی',
#  'خوزستان',
#  'فارس',
#  'هرمزگان',
#  'مازندران',
#  'یزد',
#  'کرمان',
#  'آذربایجان شرقی',
#  'قم',
#  'گیلان',
#  'سیستان و بلوچستان',
#  'سمنان',
#  'البرز',
#  'بوشهر']

# %%
fig = px.histogram(merged_data, x="Province", title='Histogram of Most Searched Provinces')
fig.show()

# %%
not_in_top = []
for city in merged_data[merged_data['2016 Census']>500000]['AcceptString'].unique():
    if city not in top_cities:
        not_in_top.append(city)
print(not_in_top)
# Out:
# ['اردبیل', 'ارومیه', 'همدان']
